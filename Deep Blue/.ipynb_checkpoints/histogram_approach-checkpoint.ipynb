# %%
import cv2
img = cv2.imread('D:\Deep Blue\test images\pot1.jfif',0)
hist = cv2.calcHist([img],[0],None,[256],[0,256])

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('test images/pot01.jfif')#pot07,img22.jfif,p77,pot01.jfif,pot02.jpg,pot06.jfif
img33=img
# img = cv2.imread('test images\pot01.jfif')
plt.hist(img.ravel(),256,[0,256]); plt.show()
plt.imshow(img33),
plt.show()

# %%
# import the necessary packages
import numpy as np
import argparse
import cv2
 
# construct the argument parse and parse the arguments
# ap = argparse.ArgumentParser()
# ap.add_argument("-i", "--image", help = "path to the image file")
# ap.add_argument("-r", "--radius", type = int,
# 	help = "radius of Gaussian blur; must be odd")
# args = vars(ap.parse_args())
 
# load the image and convert it to grayscale
image = cv2.imread('test images/pot01.jfif')#pot07,img22.jfif,p77,pot01.jfif,pot02.jpg,pot06.jfif
orig = image.copy()
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# the area of the image with the largest intensity value
(minVal, maxVal, minLoc, maxLoc) = cv2.minMaxLoc(gray)
cv2.circle(image, maxLoc, 5, (255, 0, 0), 2)
 
# display the results of the naive attempt
# cv2.imshow("Naive", image)
# Out:
# array([[[ 72,  61,  71],
#         [ 91,  80,  88],
#         [ 82,  71,  79],
#         ...,
#         [ 85,  73,  73],
#         [ 90,  78,  78],
#         [ 84,  72,  72]],
#
#        [[ 73,  62,  70],
#         [ 80,  69,  77],
#         [ 81,  70,  78],
#         ...,
#         [ 88,  76,  76],
#         [ 93,  81,  81],
#         [ 86,  74,  74]],
#
#        [[ 87,  76,  84],
#         [ 90,  79,  87],
#         [ 65,  54,  62],
#         ...,
#         [ 88,  76,  76],
#         [ 96,  84,  84],
#         [ 84,  72,  72]],
#
#        ...,
#
#        [[ 76,  65,  61],
#         [ 97,  86,  82],
#         [ 75,  64,  60],
#         ...,
#         [175, 225, 237],
#         [159, 209, 221],
#         [144, 194, 206]],
#
#        [[114, 105, 102],
#         [116, 107, 104],
#         [133, 124, 121],
#         ...,
#         [153, 211, 217],
#         [135, 193, 199],
#         [153, 211, 217]],
#
#        [[105,  96,  93],
#         [108,  99,  96],
#         [117, 108, 105],
# ...

# %%
gray = cv2.GaussianBlur(gray, (11, 11), 0)
(minVal, maxVal, minLoc, maxLoc) = cv2.minMaxLoc(gray)
image = orig.copy()
cv2.circle(image, minLoc, 11, (255, 0, 0), 2)
 
# display the results of our newly improved method
cv2.imshow("Robust", image)
cv2.waitKey(0)
# Out:
# -1
